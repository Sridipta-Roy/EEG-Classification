# %%
# %pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: numpy<2.0.0,>=1.21.0 in c:\users\sridi\anaconda3\lib\site-packages (from -r ../requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: pandas<3.0.0,>=1.3.0 in c:\users\sridi\anaconda3\lib\site-packages (from -r ../requirements.txt (line 3)) (2.1.1)
# Requirement already satisfied: scipy<2.0.0,>=1.7.0 in c:\users\sridi\anaconda3\lib\site-packages (from -r ../requirements.txt (line 4)) (1.16.3)
# Requirement already satisfied: mne<1.11.0,>=1.0.0 in c:\users\sridi\anaconda3\lib\site-packages (from -r ../requirements.txt (line 7)) (1.10.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\sridi\anaconda3\lib\site-packages (from -r ../requirements.txt (line 8)) (1.5.0)
# Requirement already satisfied: pyedflib>=0.1.30 in c:\users\sridi\anaconda3\lib\site-packages (from -r ../requirements.txt (line 9)) (0.1.42)
# Requirement already satisfied: matplotlib<4.0.0,>=3.4.0 in c:\users\sridi\anaconda3\lib\site-packages (from -r ../requirements.txt (line 15)) (3.8.3)
# Requirement already satisfied: seaborn<1.0.0,>=0.11.0 in c:\users\sridi\anaconda3\lib\site-packages (from -r ../requirements.txt (line 16)) (0.13.2)
# Requirement already satisfied: plotly<6.0.0,>=5.0.0 in c:\users\sridi\anaconda3\lib\site-packages (from -r ../requirements.txt (line 17)) (5.24.1)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.0.0 in c:\users\sridi\anaconda3\lib\site-packages (from -r ../requirements.txt (line 20)) (1.5.1)
# Requirement already satisfied: xgboost>=1.5.0 in c:\users\sridi\anaconda3\lib\site-packages (from -r ../requirements.txt (line 21)) (3.1.1)
# Requirement already satisfied: lightgbm>=3.3.0 in c:\users\sridi\anaconda3\lib\site-packages (from -r ../requirements.txt (line 22)) (4.6.0)
# Requirement already satisfied: imbalanced-learn>=0.9.0 in c:\users\sridi\anaconda3\lib\site-packages (from -r ../requirements.txt (line 23)) (0.12.3)
# Requirement already satisfied: tensorflow<3.0.0,>=2.8.0 in c:\users\sridi\anaconda3\lib\site-packages (from -r ../requirements.txt (line 26)) (2.16.1)
# Requirement already satisfied: keras>=2.8.0 in c:\users\sridi\anaconda3\lib\site-packages (from -r ../requirements.txt (line 27)) (3.3.3)
# Requirement already satisfied: tsfresh>=0.19.0 in c:\users\sridi\anaconda3\lib\site-packages (from -r ../requirements.txt (line 31)) (0.21.1)
# Requirement already satisfied: statsmodels>=0.13.0 in c:\users\sridi\anaconda3\lib\site-packages (from -r ../requirements.txt (line 34)) (0.14.2)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\sridi\anaconda3\lib\site-packages (from -r ../requirements.txt (line 37)) (4.66.4)
# Requirement already satisfied: joblib>=1.1.0 in c:\users\sridi\anaconda3\lib\site-packages (from -r ../requirements.txt (line 38)) (1.4.2)
# Requirement already satisfied: pyyaml>=6.0 in c:\users\sridi\anaconda3\lib\site-packages (from -r ../requirements.txt (line 39)) (6.0.1)
# Requirement already satisfied: jupyter>=1.0.0 in c:\users\sridi\anaconda3\lib\site-packages (from -r ../requirements.txt (line 42)) (1.0.0)
# Requirement already satisfied: ipykernel>=6.0.0 in c:\users\sridi\anaconda3\lib\site-packages (from -r ../requirements.txt (line 43)) (6.28.0)
# Requirement already satisfied: ipywidgets>=7.6.0 in c:\users\sridi\anaconda3\lib\site-packages (from -r ../requirements.txt (line 44)) (8.1.1)
# Requirement already satisfied: notebook>=6.4.0 in c:\users\sridi\anaconda3\lib\site-packages (from -r ../requirements.txt (line 45)) (7.0.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sridi\anaconda3\lib\site-packages (from pandas<3.0.0,>=1.3.0->-r ../requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sridi\anaconda3\lib\site-packages (from pandas<3.0.0,>=1.3.0->-r ../requirements.txt (line 3)) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\sridi\anaconda3\lib\site-packages (from pandas<3.0.0,>=1.3.0->-r ../requirements.txt (line 3)) (2023.3)
# Requirement already satisfied: decorator in c:\users\sridi\anaconda3\lib\site-packages (from mne<1.11.0,>=1.0.0->-r ../requirements.txt (line 7)) (5.0.9)
# Requirement already satisfied: jinja2 in c:\users\sridi\anaconda3\lib\site-packages (from mne<1.11.0,>=1.0.0->-r ../requirements.txt (line 7)) (3.1.5)
# Requirement already satisfied: lazy-loader>=0.3 in c:\users\sridi\anaconda3\lib\site-packages (from mne<1.11.0,>=1.0.0->-r ../requirements.txt (line 7)) (0.4)
# Requirement already satisfied: packaging in c:\users\sridi\anaconda3\lib\site-packages (from mne<1.11.0,>=1.0.0->-r ../requirements.txt (line 7)) (23.2)
# Requirement already satisfied: pooch>=1.5 in c:\users\sridi\anaconda3\lib\site-packages (from mne<1.11.0,>=1.0.0->-r ../requirements.txt (line 7)) (1.8.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sridi\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.4.0->-r ../requirements.txt (line 15)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sridi\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.4.0->-r ../requirements.txt (line 15)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sridi\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.4.0->-r ../requirements.txt (line 15)) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sridi\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.4.0->-r ../requirements.txt (line 15)) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\sridi\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.4.0->-r ../requirements.txt (line 15)) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sridi\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.4.0->-r ../requirements.txt (line 15)) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\sridi\anaconda3\lib\site-packages (from plotly<6.0.0,>=5.0.0->-r ../requirements.txt (line 17)) (8.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\sridi\anaconda3\lib\site-packages (from scikit-learn<2.0.0,>=1.0.0->-r ../requirements.txt (line 20)) (3.6.0)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\sridi\anaconda3\lib\site-packages (from tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\sridi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\sridi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\sridi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\sridi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\sridi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\sridi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\sridi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\sridi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\sridi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\sridi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (4.25.8)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sridi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (2.32.2)
# Requirement already satisfied: setuptools in c:\users\sridi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\sridi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sridi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\sridi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\sridi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\sridi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (1.75.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\sridi\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (2.16.2)
# Requirement already satisfied: rich in c:\users\sridi\anaconda3\lib\site-packages (from keras>=2.8.0->-r ../requirements.txt (line 27)) (13.9.4)
# Requirement already satisfied: namex in c:\users\sridi\anaconda3\lib\site-packages (from keras>=2.8.0->-r ../requirements.txt (line 27)) (0.1.0)
# Requirement already satisfied: optree in c:\users\sridi\anaconda3\lib\site-packages (from keras>=2.8.0->-r ../requirements.txt (line 27)) (0.16.0)
# Requirement already satisfied: patsy>=0.4.1 in c:\users\sridi\anaconda3\lib\site-packages (from tsfresh>=0.19.0->-r ../requirements.txt (line 31)) (0.5.6)
# Requirement already satisfied: stumpy>=1.7.2 in c:\users\sridi\anaconda3\lib\site-packages (from tsfresh>=0.19.0->-r ../requirements.txt (line 31)) (1.13.0)
# Requirement already satisfied: cloudpickle in c:\users\sridi\anaconda3\lib\site-packages (from tsfresh>=0.19.0->-r ../requirements.txt (line 31)) (2.2.1)
# Requirement already satisfied: colorama in c:\users\sridi\anaconda3\lib\site-packages (from tqdm>=4.62.0->-r ../requirements.txt (line 37)) (0.4.6)
# Requirement already satisfied: qtconsole in c:\users\sridi\anaconda3\lib\site-packages (from jupyter>=1.0.0->-r ../requirements.txt (line 42)) (5.5.1)
# Requirement already satisfied: jupyter-console in c:\users\sridi\anaconda3\lib\site-packages (from jupyter>=1.0.0->-r ../requirements.txt (line 42)) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\sridi\anaconda3\lib\site-packages (from jupyter>=1.0.0->-r ../requirements.txt (line 42)) (7.10.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\sridi\anaconda3\lib\site-packages (from ipykernel>=6.0.0->-r ../requirements.txt (line 43)) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\sridi\anaconda3\lib\site-packages (from ipykernel>=6.0.0->-r ../requirements.txt (line 43)) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\sridi\anaconda3\lib\site-packages (from ipykernel>=6.0.0->-r ../requirements.txt (line 43)) (8.25.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\sridi\anaconda3\lib\site-packages (from ipykernel>=6.0.0->-r ../requirements.txt (line 43)) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\sridi\anaconda3\lib\site-packages (from ipykernel>=6.0.0->-r ../requirements.txt (line 43)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\sridi\anaconda3\lib\site-packages (from ipykernel>=6.0.0->-r ../requirements.txt (line 43)) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\sridi\anaconda3\lib\site-packages (from ipykernel>=6.0.0->-r ../requirements.txt (line 43)) (1.6.0)
# Requirement already satisfied: psutil in c:\users\sridi\anaconda3\lib\site-packages (from ipykernel>=6.0.0->-r ../requirements.txt (line 43)) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\sridi\anaconda3\lib\site-packages (from ipykernel>=6.0.0->-r ../requirements.txt (line 43)) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\sridi\anaconda3\lib\site-packages (from ipykernel>=6.0.0->-r ../requirements.txt (line 43)) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\sridi\anaconda3\lib\site-packages (from ipykernel>=6.0.0->-r ../requirements.txt (line 43)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in c:\users\sridi\anaconda3\lib\site-packages (from ipywidgets>=7.6.0->-r ../requirements.txt (line 44)) (4.0.14)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in c:\users\sridi\anaconda3\lib\site-packages (from ipywidgets>=7.6.0->-r ../requirements.txt (line 44)) (3.0.15)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\sridi\anaconda3\lib\site-packages (from notebook>=6.4.0->-r ../requirements.txt (line 45)) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\sridi\anaconda3\lib\site-packages (from notebook>=6.4.0->-r ../requirements.txt (line 45)) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in c:\users\sridi\anaconda3\lib\site-packages (from notebook>=6.4.0->-r ../requirements.txt (line 45)) (4.0.13)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\sridi\anaconda3\lib\site-packages (from notebook>=6.4.0->-r ../requirements.txt (line 45)) (0.2.3)
# Requirement already satisfied: jedi>=0.16 in c:\users\sridi\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r ../requirements.txt (line 43)) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\sridi\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r ../requirements.txt (line 43)) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\sridi\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r ../requirements.txt (line 43)) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\sridi\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r ../requirements.txt (line 43)) (0.2.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\sridi\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.0.0->-r ../requirements.txt (line 43)) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\sridi\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.0.0->-r ../requirements.txt (line 43)) (305.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\sridi\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 45)) (4.11.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\sridi\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 45)) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\sridi\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 45)) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\sridi\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 45)) (0.4.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\sridi\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 45)) (5.9.2)
# Requirement already satisfied: overrides>=5.0 in c:\users\sridi\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 45)) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\sridi\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 45)) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\sridi\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 45)) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\sridi\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 45)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\sridi\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 45)) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\sridi\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 45)) (1.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sridi\anaconda3\lib\site-packages (from jinja2->mne<1.11.0,>=1.0.0->-r ../requirements.txt (line 7)) (2.1.3)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\sridi\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=6.4.0->-r ../requirements.txt (line 45)) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\sridi\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=6.4.0->-r ../requirements.txt (line 45)) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\sridi\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.4.0->-r ../requirements.txt (line 45)) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\sridi\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.4.0->-r ../requirements.txt (line 45)) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\sridi\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.4.0->-r ../requirements.txt (line 45)) (4.19.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\sridi\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r ../requirements.txt (line 42)) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\sridi\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r ../requirements.txt (line 42)) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\sridi\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r ../requirements.txt (line 42)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\sridi\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r ../requirements.txt (line 42)) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\sridi\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r ../requirements.txt (line 42)) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\sridi\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r ../requirements.txt (line 42)) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\sridi\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r ../requirements.txt (line 42)) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\sridi\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r ../requirements.txt (line 42)) (1.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sridi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sridi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sridi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sridi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (2024.6.2)
# Requirement already satisfied: numba>=0.57.1 in c:\users\sridi\anaconda3\lib\site-packages (from stumpy>=1.7.2->tsfresh>=0.19.0->-r ../requirements.txt (line 31)) (0.59.1)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\sridi\anaconda3\lib\site-packages (from qtconsole->jupyter>=1.0.0->-r ../requirements.txt (line 42)) (2.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sridi\anaconda3\lib\site-packages (from rich->keras>=2.8.0->-r ../requirements.txt (line 27)) (2.2.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sridi\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 45)) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\sridi\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 45)) (21.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\sridi\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (0.43.0)
# Requirement already satisfied: webencodings in c:\users\sridi\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter>=1.0.0->-r ../requirements.txt (line 42)) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\sridi\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.0.0->-r ../requirements.txt (line 43)) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sridi\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.4.0->-r ../requirements.txt (line 45)) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sridi\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.4.0->-r ../requirements.txt (line 45)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sridi\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.4.0->-r ../requirements.txt (line 45)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\sridi\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.4.0->-r ../requirements.txt (line 45)) (0.10.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\sridi\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 45)) (2.0.7)
# Requirement already satisfied: rfc3339-validator in c:\users\sridi\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 45)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\sridi\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 45)) (0.1.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sridi\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=2.8.0->-r ../requirements.txt (line 27)) (0.1.0)
# Requirement already satisfied: fastjsonschema in c:\users\sridi\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 45)) (2.16.2)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\sridi\anaconda3\lib\site-packages (from numba>=0.57.1->stumpy>=1.7.2->tsfresh>=0.19.0->-r ../requirements.txt (line 31)) (0.42.0)
# Requirement already satisfied: wcwidth in c:\users\sridi\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.0.0->-r ../requirements.txt (line 43)) (0.2.5)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sridi\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\sridi\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\sridi\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<3.0.0,>=2.8.0->-r ../requirements.txt (line 26)) (3.0.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sridi\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->-r ../requirements.txt (line 42)) (2.5)
# Requirement already satisfied: executing in c:\users\sridi\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.0.0->-r ../requirements.txt (line 43)) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\sridi\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.0.0->-r ../requirements.txt (line 43)) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\sridi\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.0.0->-r ../requirements.txt (line 43)) (0.2.2)
# Requirement already satisfied: fqdn in c:\users\sridi\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 45)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\sridi\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 45)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\sridi\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 45)) (2.1)
# Requirement already satisfied: uri-template in c:\users\sridi\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 45)) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\sridi\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 45)) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\sridi\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 45)) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\sridi\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 45)) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\sridi\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.4.0->-r ../requirements.txt (line 45)) (1.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import warnings
from tqdm import tqdm
import joblib

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (classification_report, confusion_matrix, 
                            accuracy_score, precision_score, recall_score,
                            f1_score, roc_auc_score, roc_curve)

import tensorflow as tf
from tensorflow import keras

# Custom modules
import sys
sys.path.append('../src')
from models import TraditionalMLModels, DeepLearningModels, get_callbacks

warnings.filterwarnings('ignore')

# %%
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
# %matplotlib inline

# Set random seeds
np.random.seed(42)
tf.random.set_seed(42)

# %%
print(f"TensorFlow version: {tf.__version__}")
print(f"GPU Available: {tf.config.list_physical_devices('GPU')}")
# Out:
# TensorFlow version: 2.16.1
# GPU Available: []
